# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
perth = "/Users/jenny.wade@schibsted.com/Documents/GitHub/Projekt/all_perth_310121.csv"
perth_data = pd.read_csv(perth)

# %%
perth_data.head()
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160 2003-01-01     18300  Cockburn Central Station
# 1        351         139 2013-01-01     26900           Kwinana Station
# 2        719          86 1979-01-01     22600           Challis Station
# 3        651          59 1953-01-01     17900           Midland Station
# 4        466         131 1998-01-01     11200        Bassendean Station
#
#    NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# ...

# %%
perth_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33656 entries, 0 to 33655
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ADDRESS           33656 non-null  object
#  1   SUBURB            33656 non-null  object
#  2   PRICE             33656 non-null  int64
#  3   BEDROOMS          33656 non-null  int64
#  4   BATHROOMS         33656 non-null  int64
#  5   GARAGE            31178 non-null  float64
#  6   LAND_AREA         33656 non-null  int64
#  7   FLOOR_AREA        33656 non-null  int64
#  8   BUILD_YEAR        30501 non-null  float64
#  9   CBD_DIST          33656 non-null  int64
#  10  NEAREST_STN       33656 non-null  object
#  11  NEAREST_STN_DIST  33656 non-null  int64
#  12  DATE_SOLD         33656 non-null  object
#  13  POSTCODE          33656 non-null  int64
#  14  LATITUDE          33656 non-null  float64
#  15  LONGITUDE         33656 non-null  float64
# ...

# %%
plt.figure(figsize=(12,10))
cor = perth_data .corr()
sns.heatmap(cor, annot=True)
plt.show()

# %%
perth_data.dtypes
# Out:
# ADDRESS                     string
# SUBURB                      string
# PRICE                        Int64
# BEDROOMS                     Int64
# BATHROOMS                    Int64
# GARAGE                       Int64
# LAND_AREA                    Int64
# FLOOR_AREA                   Int64
# BUILD_YEAR          datetime64[ns]
# CBD_DIST                     Int64
# NEAREST_STN                 string
# NEAREST_STN_DIST             Int64
# DATE_SOLD           datetime64[ns]
# POSTCODE                     Int64
# LATITUDE                   Float64
# LONGITUDE                  Float64
# NEAREST_SCH                 string
# NEAREST_SCH_DIST           Float64
# NEAREST_SCH_RANK             Int64
# dtype: object

# %%
perth_data['DATE_SOLD'] = pd.to_datetime(perth_data['DATE_SOLD'])
perth_data['BUILD_YEAR'] = pd.to_datetime(perth_data['BUILD_YEAR'], format='%Y')

# %%
perth_data = perth_data.convert_dtypes()

# %%
#Counting number of nan values
nan_per_col = perth_data.isna().sum()
print(nan_per_col)
# Out:
# ADDRESS                 0
# SUBURB                  0
# PRICE                   0
# BEDROOMS                0
# BATHROOMS               0
# GARAGE                  0
# LAND_AREA               0
# FLOOR_AREA              0
# BUILD_YEAR           3155
# CBD_DIST                0
# NEAREST_STN             0
# NEAREST_STN_DIST        0
# DATE_SOLD               0
# POSTCODE                0
# LATITUDE                0
# LONGITUDE               0
# NEAREST_SCH             0
# NEAREST_SCH_DIST        0
# NEAREST_SCH_RANK    10952
# dtype: int64

# %%
#Filling garage with 0 as it's likely that these houses has no garage.
perth_data['GARAGE'] = perth_data['GARAGE'].fillna(0)

# %%
print(perth_data['BEDROOMS'].unique())
# Out:
# <IntegerArray>
# [4, 3, 2, 5, 6, 7, 1, 8, 10, 9]
# Length: 10, dtype: Int64

# %%
plt.hist(perth_data['BEDROOMS'])
plt.show()

# %%
sns.lineplot(x=perth_data['BEDROOMS'], y=perth_data['PRICE'])
plt.show()
